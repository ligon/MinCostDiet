# %% [markdown]
# # USDA Nutrition DataBase

# %% [markdown]
# The USDA maintains a database of nutritional information, where
# different kinds of food are identified by an NDB number.  They do
# not provide any data on prices.
#
# To look up nutritional information, use api provided by the USDA at
# [https://ndb.nal.usda.gov/ndb/doc/index](https://ndb.nal.usda.gov/ndb/doc/index).   You&rsquo;ll need to sign up for a
# free api key (see directions on page), then supply that key here:

# %%
apikey = "inIyO1begWSRqsYtxS7m6p09PSyq7Qiw7fxzV2qN"

# %% [markdown]
# # Data on Prices

# %% [markdown]
# Here&rsquo;s an effort to describe some different kinds of food, along with
# data on food prices.  This is all just based on my last trip to the
# grocery store, except that I&rsquo;ve used the USDA database to look up NDB
# numbers.  Note that one may need to protect leading zeros with &ldquo;&rdquo; for
# the NDB numbers.
#
# Also note that some kinds of foods need to have unit weights (in
# grams) supplied under &ldquo;Units&rdquo;; e.g., extra large eggs are taken to
# each way 56g.  These conversions can also often be found on the USDA
# NDB website.  Othertimes not&#x2014;I still need to weigh a crumpet.
#
# <table id="org0312ec8" border="2" cellspacing="0" cellpadding="6" rules="groups" frame="hsides">
#
#
# <colgroup>
# <col  class="org-left" />
#
# <col  class="org-right" />
#
# <col  class="org-left" />
#
# <col  class="org-right" />
#
# <col  class="org-left" />
#
# <col  class="org-left" />
#
# <col  class="org-right" />
# </colgroup>
# <thead>
# <tr>
# <th scope="col" class="org-left">Food</th>
# <th scope="col" class="org-right">Quantity</th>
# <th scope="col" class="org-left">Units</th>
# <th scope="col" class="org-right">Price</th>
# <th scope="col" class="org-left">Date</th>
# <th scope="col" class="org-left">Location</th>
# <th scope="col" class="org-right">NDB</th>
# </tr>
# </thead>
#
# <tbody>
# <tr>
# <td class="org-left">Milk, 2% fat</td>
# <td class="org-right">1</td>
# <td class="org-left">gallon</td>
# <td class="org-right">4.99</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45226447</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Eggs, extra large</td>
# <td class="org-right">12</td>
# <td class="org-left">56g</td>
# <td class="org-right">3.59</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45208918</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Crumpets</td>
# <td class="org-right">6</td>
# <td class="org-left">units</td>
# <td class="org-right">3.19</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45324369</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Bananas</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">3.15</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">&ldquo;09040&rdquo;</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Carrots, Organic</td>
# <td class="org-right">2</td>
# <td class="org-left">pound</td>
# <td class="org-right">2.29</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">11124</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Cauliflower</td>
# <td class="org-right">2.51</td>
# <td class="org-left">pound</td>
# <td class="org-right">4.24</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">11135</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Endive, Red</td>
# <td class="org-right">1.26</td>
# <td class="org-left">pound</td>
# <td class="org-right">6.27</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">11213</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Figs, black mission</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">4.98</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45170327</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Leeks, Organic</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">1.29</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">11246</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Lettuce, Little Gem</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">5.98</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45276886</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Mushrooms, King Oyster</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">12</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45218868</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Onion, yellow</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">0.39</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45339306</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Orange juice</td>
# <td class="org-right">0.5</td>
# <td class="org-left">gallon</td>
# <td class="org-right">8.98</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45213207</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Parsnip</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">1.98</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">11298</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Potato, marble mix</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">2.59</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45169597</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Rhubarb</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">1.84</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">&ldquo;09307&rdquo;</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Potato, russet</td>
# <td class="org-right">10</td>
# <td class="org-left">pound</td>
# <td class="org-right">2.98</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">45364251</td>
# </tr>
#
#
# <tr>
# <td class="org-left">Squash, Zucchini</td>
# <td class="org-right">1</td>
# <td class="org-left">pound</td>
# <td class="org-right">1.49</td>
# <td class="org-left"><span class="timestamp-wrapper"><span class="timestamp">[2019-09-14 Sat]</span></span></td>
# <td class="org-left">Monterey Market, Berkeley</td>
# <td class="org-right">11477</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # Nutritional information

# %%
import ndb
import pandas as pd
from cfe.df_utils import orgtbl_to_df, df_to_orgtbl

df = pd.read_csv('./Data/ligons_shopping.csv',dtype=str)

D = {}
for food in  df.Food.tolist():
    D[food] = ndb.ndb_report(apikey,df.loc[df.Food==food,:].NDB).Quantity

D = pd.DataFrame(D)

print(D.T)
# Out:
#                        Caffeine Calcium, Ca Carbohydrate, by difference  \
# Milk, 2% fat                NaN         146                        5.83
# Eggs, extra large           NaN          71                        0.00
# Crumpets                    NaN           0                       40.72
# Bananas                       0           5                       22.84
# Carrots, Organic              0          33                        9.58
# Cauliflower                   0          22                        4.97
# Endive, Red                   0          52                        3.35
# Figs, black mission         NaN         150                       72.50
# Leeks, Organic                0          59                       14.15
# Lettuce, Little Gem         NaN          24                        2.35
# Mushrooms, King Oyster      NaN           0                        1.18
# Onion, yellow               NaN          27                        9.09
# Orange juice                NaN           8                       10.83
# Parsnip                       0          36                       17.99
# Potato, marble mix          NaN          14                       17.57
# Rhubarb                       0          86                        4.54
# Potato, russet              NaN          14                       17.57
# Squash, Zucchini              0          16                        3.11
#
#                        Cholesterol Energy Fatty acids, total monounsaturated  \
# Milk, 2% fat                    10     58                                NaN
# Eggs, extra large              375    143                              3.570
# Crumpets                         0    181                                NaN
# Bananas                          0     89                              0.032
# Carrots, Organic                 0     41                              0.012
# Cauliflower                      0     25                              0.034
# Endive, Red                      0     17                              0.004
# Figs, black mission              0    300                                NaN
# Leeks, Organic                   0     61                              0.004
# Lettuce, Little Gem              0     12                                NaN
# Mushrooms, King Oyster           0     48                                NaN
# Onion, yellow                    0     40                                NaN
# Orange juice                   NaN     46                                NaN
# Parsnip                          0     75                              0.112
# Potato, marble mix               0     74                                NaN
# Rhubarb                          0     21                              0.039
# Potato, russet                   0     74                                NaN
# Squash, Zucchini                 0     17                              0.011
#
#                        Fatty acids, total polyunsaturated  \
# Milk, 2% fat                                          NaN
# Eggs, extra large                                   1.790
# Crumpets                                              NaN
# Bananas                                             0.073
# Carrots, Organic                                    0.102
# Cauliflower                                         0.031
# Endive, Red                                         0.087
# Figs, black mission                                   NaN
# Leeks, Organic                                      0.166
# Lettuce, Little Gem                                   NaN
# Mushrooms, King Oyster                                NaN
# Onion, yellow                                         NaN
# Orange juice                                          NaN
# Parsnip                                             0.047
# Potato, marble mix                                    NaN
# Rhubarb                                             0.099
# Potato, russet                                        NaN
# Squash, Zucchini                                    0.091
#
#                        Fatty acids, total saturated Fatty acids, total trans  \
# Milk, 2% fat                                  1.250                    0.000
# Eggs, extra large                             3.570                    0.000
# Crumpets                                      0.000                    0.000
# Bananas                                       0.112                    0.000
# Carrots, Organic                              0.032                    0.000
# Cauliflower                                   0.130                    0.000
# Endive, Red                                   0.048                    0.000
# Figs, black mission                           0.000                    0.000
# Leeks, Organic                                0.040                    0.000
# Lettuce, Little Gem                           0.000                    0.000
# Mushrooms, King Oyster                        0.000                    0.000
# Onion, yellow                                 0.000                    0.000
# Orange juice                                    NaN                      NaN
# Parsnip                                       0.050                    0.000
# Potato, marble mix                            0.000                      NaN
# Rhubarb                                       0.053                    0.000
# Potato, russet                                0.000                    0.000
# Squash, Zucchini                              0.084                    0.000
#
#                        Fiber, total dietary   ...    Vitamin A, RAE  \
# Milk, 2% fat                            0.0   ...               NaN
# Eggs, extra large                       0.0   ...               NaN
# Crumpets                                2.3   ...               NaN
# Bananas                                 2.6   ...                 3
# Carrots, Organic                        2.8   ...               835
# Cauliflower                             2.0   ...                 0
# Endive, Red                             3.1   ...               108
# Figs, black mission                    12.5   ...               NaN
# Leeks, Organic                          1.8   ...                83
# Lettuce, Little Gem                     1.2   ...               NaN
# Mushrooms, King Oyster                  1.2   ...               NaN
# Onion, yellow                           1.8   ...               NaN
# Orange juice                            NaN   ...               NaN
# Parsnip                                 4.9   ...                 0
# Potato, marble mix                      1.4   ...               NaN
# Rhubarb                                 1.8   ...                 5
# Potato, russet                          1.4   ...               NaN
# Squash, Zucchini                        1.0   ...                10
#
#                        Vitamin B-12 Vitamin B-6  \
# Milk, 2% fat                    NaN         NaN
# Eggs, extra large              0.86       0.143
# Crumpets                        NaN         NaN
# Bananas                        0.00       0.367
# Carrots, Organic               0.00       0.138
# Cauliflower                    0.00       0.184
# Endive, Red                    0.00       0.020
# Figs, black mission             NaN         NaN
# Leeks, Organic                 0.00       0.233
# Lettuce, Little Gem             NaN         NaN
# Mushrooms, King Oyster          NaN         NaN
# Onion, yellow                   NaN       0.127
# Orange juice                    NaN         NaN
# Parsnip                        0.00       0.090
# Potato, marble mix              NaN       0.135
# Rhubarb                        0.00       0.024
# Potato, russet                  NaN         NaN
# Squash, Zucchini               0.00       0.163
#
#                        Vitamin C, total ascorbic acid Vitamin D  \
# Milk, 2% fat                                      0.5        42
# Eggs, extra large                                 0.0        71
# Crumpets                                          0.0       NaN
# Bananas                                           8.7         0
# Carrots, Organic                                  5.9         0
# Cauliflower                                      48.2         0
# Endive, Red                                       6.5         0
# Figs, black mission                               0.0       NaN
# Leeks, Organic                                   12.0         0
# Lettuce, Little Gem                               4.2       NaN
# Mushrooms, King Oyster                            4.2       NaN
# Onion, yellow                                     7.6         0
# Orange juice                                     30.0       NaN
# Parsnip                                          17.0         0
# Potato, marble mix                               18.2       NaN
# Rhubarb                                           8.0         0
# Potato, russet                                   18.2       NaN
# Squash, Zucchini                                 17.9         0
#
#                        Vitamin D (D2 + D3) Vitamin E (alpha-tocopherol)  \
# Milk, 2% fat                           NaN                          NaN
# Eggs, extra large                      NaN                          NaN
# Crumpets                               NaN                          NaN
# Bananas                                0.0                         0.10
# Carrots, Organic                       0.0                         0.66
# Cauliflower                            0.0                         0.08
# Endive, Red                            0.0                         0.44
# Figs, black mission                    NaN                          NaN
# Leeks, Organic                         0.0                         0.92
# Lettuce, Little Gem                    NaN                          NaN
# Mushrooms, King Oyster                 NaN                          NaN
# Onion, yellow                          NaN                          NaN
# Orange juice                           NaN                          NaN
# Parsnip                                0.0                         1.49
# Potato, marble mix                     NaN                          NaN
# Rhubarb                                0.0                         0.27
# Potato, russet                         NaN                          NaN
# Squash, Zucchini                       0.0                         0.12
#
#                        Vitamin K (phylloquinone)  Water Zinc, Zn
# Milk, 2% fat                                 NaN    NaN      NaN
# Eggs, extra large                            NaN    NaN     1.07
# Crumpets                                     NaN    NaN      NaN
# Bananas                                      0.5  74.91     0.15
# Carrots, Organic                            13.2  88.29     0.24
# Cauliflower                                 15.5  92.07     0.27
# Endive, Red                                231.0  93.79     0.79
# Figs, black mission                          NaN    NaN      NaN
# Leeks, Organic                              47.0  83.00     0.12
# Lettuce, Little Gem                          NaN    NaN      NaN
# Mushrooms, King Oyster                       NaN    NaN      NaN
# Onion, yellow                                NaN    NaN      NaN
# Orange juice                                 NaN    NaN      NaN
# Parsnip                                     22.5  79.53     0.59
# Potato, marble mix                           NaN    NaN     0.20
# Rhubarb                                     29.3  93.61     0.10
# Potato, russet                               NaN    NaN      NaN
# Squash, Zucchini                             4.3  94.79     0.32
#
# [18 rows x 33 columns]
